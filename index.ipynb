# %% [markdown]
# # Scraping Concerts - Lab
#
# ## Introduction
#
# Now that you've seen how to scrape a simple website, it's time to again practice those skills on a full-fledged site!
# In this lab, you'll practice your scraping skills on a music website: https://www.residentadvisor.net.
# ## Objectives
#
# You will be able to:
# * Create a full scraping pipeline that involves traversing over many pages of a website, dealing with errors and storing data

# %% [markdown]
# ## View the Website
#
# For this lab, you'll be scraping the https://www.residentadvisor.net website. Start by navigating to the events page [here](https://www.residentadvisor.net/events) in your browser.
#
# <img src="images/ra.png">

# %%
# Load the https://www.residentadvisor.net/events page in your browser.

# %% [markdown]
# ## Open the Inspect Element Feature
#
# Next, open the inspect element feature from your web browser in order to preview the underlying HTML associated with the page.

# %%
# Open the inspect element feature in your browser
from bs4 import BeautifulSoup
import requests
import pandas as pd
import time

# %%
html_page = requests.get('https://www.residentadvisor.net/events/us/georgia/week/2019-07-01')
soup = BeautifulSoup(html_page.content, 'lxml')

# %%
soup.prettify
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
# <html lang="en,ja,es">
# <head id="_x1"><title>
# 	RA: Events in Georgia, United States of America
# </title><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><meta content="en,ja,es" http-equiv="content-language"/><meta content="RA: Resident Advisor" name="Description"/><meta content="RA, residentadvisor, resident, advisor, music, ra, events, in, georgia, united, states, america" name="Keywords"/><meta content="Resident Advisor" name="Author"/><meta content="Resident Advisor" property="og:site_name"/><meta content="712773712080127" property="fb:app_id"/><link href="/bundles/default-css?v=nA9uavMPeFtRavUj5m2TICqAtGhp7tbC5z-iw5vW6k81" rel="stylesheet"/>
# <meta content="app-id=981952703, app-argument=ra-guide://search" name="apple-itunes-app"/><link href="/bundles/cat-listings-css?v=qgpSmyPbylOKeJFqy2yvCrTgAsw9yQYcJtLKS_vPO6s1" rel="stylesheet"/>
# <link href="/favicon.ico" rel="icon" type="image/vnd.microsoft.icon"/><link color="#000000" href="/images/ra_icon.svg" rel="mask-icon"/><script src="/bundles/default-js?v=C_jhfJfZn1P5UEleCb3LOK9nhVUqeGNpheu--vQ1UT01"></script>
# <script>
# 	    googletag.cmd.push(function () { googletag.pubads().setTargeting("Page", "/events/us/georgia").setTargeting("Category", "Listings").setTargeting("Section", "Events").setTargeting("Content", "EventsHome").setTargeting("Country", "US").setTargeting("Area", "Georgia"); });
#          console.info('Interested in our code? Join us and help write it - https://www.residentadvisor.net/about/jobs');
#     </script>
# <script>
#             const widthTest = false;
#         if (window.screen.availWidth < 663 && window.screen.width < window.screen.height && !widthTest) {
#             document.write('<meta name="viewport" content="width=328">');
#         } else {
#             document.write('<meta name="viewport" content="width=device-width, initial-scale=1">');
#         }
#     </script>
# <script>
#             if (typeof dataLayer === 'undefined') {
#                 dataLayer = []
#             }
#         </script>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=AW-940832047"></script>
# <script>
#             window.dataLayer = window.dataLayer || [];
#             function gtag() { dataLayer.push(arguments); }
#             gtag('js', new Date());
#
#             gtag('config', 'AW-940832047');
#         </script>
# <script src="/js/dist/ReactLibs.bundle.js?637292655144076503"></script>
# <script>
#             (function (w, d, s, l, i) {
#                 w[l] = w[l] || []; w[l].push({
#                     'gtm.start':
#                         new Date().getTime(), event: 'gtm.js'
#                 }); var f = d.getElementsByTagName(s)[0],
#                     j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : ''; j.async = true; j.src =
#                         'https://www.googletagmanager.com/gtm.js?id=' + i + dl; f.parentNode.insertBefore(j, f);
#                     })(window, document, 'script', 'dataLayer', 'GTM-M269WMP');
#         </script>
# </head>
# <body id="body">
# <input id="user-id" name="user-id" type="hidden" value="0"/>
# <input id="see-ngc" name="see-ngc" type="hidden" value="false"/>
# <a name="top"></a>
# <header id="header">
# <div class="pnlLeaderWrapper">
# <div id="pnlLeader">
# <aside class="div-gpt-ad-1452773484957-6 leader"><div class="ad" id="div-gpt-ad-1452773484957-6"></div></aside>
# </div>
# </div>
# <nav class="clearfix" id="user">
# <ul style="-moz-user-select: -moz-none; -khtml-user-select: none; -webkit-user-select: none;">
# <li class="but dark arrow-down" id="basket">
# Basket
# <div class="count basket" style="display:none;"><span></span></div>
# </li>
# <li class="but subscribe desktop-only desktop-wide-only" id="nav-link">
# <a ga-event-action="subscribe-nav-link" ga-event-category="subscriptions" ga-on="click" href="/subscribe">
# <span>Subscribe</span>
# </a>
# </li>
# <li class="but arrow-down temp login" id="profile">Login / Register
# </li>
# </ul>
# </nav>
# <ul class="bbox panel" id="profile-panel">
# <li><a href="https://www.residentadvisor.net/login">Login</a></li>
# <li><a href="https://www.residentadvisor.net/register">Register</a></li>
# </ul>
# <div class="bbox panel bbox generic clearfix" id="basket-panel">
# <div class="items"></div><div class="basket-but but myra"></div>
# </div>
# <div class="notificationPanel bbox clearfix events col3" id="notificationPanel"></div>
# <div class="null" id="navContainer">
# <div id="navbar">
# <div id="logo"><a class="icon" href="/">Resident Advisor</a></div>
# <div class="modal-full-screen" id="search-bar">
# <span class="modal-close">×</span>
# <div class="modal-body" id="search-bar-internal">
# <span class="f24 mobile-only search-header">Search</span>
# <div id="search-box-div">
# <input id="search-box" placeholder="Artists, Clubs, Promoters, Cities" type="text"/>
# </div>
# <div class="but large" id="search-button">
# <a id="search" title="Search">Submit</a>
# </div>
# <div class="grey pt16 search-helper" style="display: none;">Did you mean</div>
# </div>
# </div>
# <nav class="modal-full-screen" id="nav" role="navigation">
# <div class="modal-close">×</div>
# <ul class="modal-body open" data-display="0" id="links">
# <li class="mobile-only tablet-off">
# <div id="logo-modal-nav">
# <a class="icon" ga-event-action="RA-Logo" ga-event-category="nav" ga-on="click" href="/">Resident Advisor</a>
# </div>
# </li>
# <li id="mMagazine">
# <span>
# Magazine</span>
# <ul>
# <li id="mNews"><a ga-event-action="News" ga-event-category="nav" ga-on="click" href="/news">
# News</a></li>
# <li id="mReviews"><a ga-event-action="Reviews" ga-event-category="nav" ga-on="click" href="/reviews.aspx">
# Reviews</a></li>
# <li id="mFeatures"><a ga-event-action="Features" ga-event-category="nav" ga-on="click" href="/features.aspx">
# Features</a></li>
# <li id="mFilms"><a ga-event-action="Videos" ga-event-category="nav" ga-on="click" href="/videos">
# Videos</a></li>
# </ul>
# </li>
# <li data-selected="1" id="mListings">
# <span>
# Listings</span>
# <ul>
# <li data-selected="1" id="mEvents"><a ga-event-action="Events" ga-event-category="nav" ga-on="click" href="/events">
# Events</a></li>
# <li id="mClubs"><a ga-event-action="Clubs" ga-event-category="nav" ga-on="click" href="/clubs.aspx">
# Clubs</a></li>
# <li id="mFestivals"><a ga-event-action="Festivals" ga-event-category="nav" ga-on="click" href="/festivals.aspx">
# Festivals</a></li>
# <li id="mStreamland"><a ga-event-action="Streamland" ga-event-category="nav" ga-on="click" href="/events/streamland">
# Streamland</a></li>
# </ul>
# </li>
# <li id="mMusic">
# <span>
# Music</span>
# <ul>
# <li id="mDjpages"><a ga-event-action="Artists" ga-event-category="nav" ga-on="click" href="/dj.aspx">
# Artists</a></li>
# <li id="mMixOfTheDay"><a ga-event-action="Mix of the day" ga-event-category="nav" ga-on="click" href="/news/mix-of-the-day/2020/7">
# Mix of the day</a></li>
# <li id="mCharts"><a ga-event-action="DJ Charts" ga-event-category="nav" ga-on="click" href="/dj-charts.aspx">
# DJ Charts</a></li>
# <li id="mPodcast"><a ga-event-action="Podcasts" ga-event-category="nav" ga-on="click" href="/podcast.aspx">
# Podcasts</a></li>
# </ul>
# </li>
# <li data-url="https://search.residentadvisor.net/" id="mSearch">
# <a ga-event-action="reveal-desktop" ga-event-category="search" ga-on="click" href="#">
# Search</a>
# </li>
# </ul>
# </nav>
# <div ga-event-action="burger" ga-event-category="nav" ga-on="click" id="but-links">
# <div class="icon"></div>
# </div>
# <div ga-event-action="mobile-reveal" ga-event-category="search" ga-on="click" id="but-search">
# <div class="icon"></div>
# </div>
# </div>
# <div class="add-space" id="sectionHead">
# <h1>Events</h1>
# </div>
# <link href="/bundles/autocomplete-css?v=hX3EIxBPUes4W-JFrW9vc2V9eyRDs1p9rgi0LcnlXug1" rel="stylesheet"/>
# <script src="/bundles/autocomplete?v=SCtA5z9vnBIQK6ZI-wtyD14u0Lv-S6kQhwTW5lgrMYQ1"></script>
# <script src="/bundles/analytics-js?v=pUK2ZxBTfTo6P0-8Xh1_QmhiGk4YBwWiTKDOFLGXwbg1"></script>
# </div>
# <section class="clearfix" id="subnav">
# <ul>
# <li class="on" id="subnav-all"><a href="/events">All</a></li><li id="subnav-new"><a href="/events/new">New</a></li><li id="subnav-for-you"><a href="/events/favourites">For You</a></li><li id="subnav-promoters"><a href="/promoters.aspx">Promoters</a></li><li id="subnav-submit-an-event"><a href="/submit-event.aspx">Submit an event</a></li>
# </ul>
# </section>
# </header>
# <form action="./2019-07-01?cc=us&amp;an=georgia&amp;v=week&amp;mn=07&amp;yr=2019&amp;dy=01" id="Form1" method="post">
# <div class="aspNetHidden">
# <input id="__VIEWSTATE" name="__VIEWSTATE" type="hidden" value="uJ3lVmQ5H819DhWAPYpQpq9xg3y7iSeSS6adUNDVzyCOOSrctmfti92fDPBtZyjFtnx1tvOmEdwmNEtbe124FdRHzbI="/>
# </div>
# <div class="aspNetHidden">
# <input id="__VIEWSTATEGENERATOR" name="__VIEWSTATEGENERATOR" type="hidden" value="ADA4D364"/>
# </div>
# <main>
# <script src="/bundles/sticky-js?v=v676-NN9nrtj1Xpc3-lLALpuQvn14WLF-0HBUTbxEIQ1"></script>
# <script>
#     $(document).ready(function() {
#         $('.slide')
#         .scrollSnap({
#             page: 'eventshome'
#         });
#     })
#     </script>
# <ul class="content-list events-border">
# <li class="clearfix pt1">
# <div class="page-items content" id="previous-next">
# <ul>
# <li class="but arrow-left left" id="liPrevious">
# <a ga-event-action="Previous " ga-event-category="event-listings" ga-on="click" href="/events
li><li class=""><article class="event-item clearfix" itemscope="" itemtype="http://data-vocabulary.org/Event"><span style="display:none;"><time datetime="2019-07-03T00:00" itemprop="startDate">2019-07-03T00:00</time></span><a href="/events/1273253"><img height="76" src="/images/events/flyer/2019/6/us-0627-1273253-list.jpg" width="152"/></a><div class="bbox"><h1 class="event-title" itemprop="summary"><a href="/events/1273253" itemprop="url" title="Event details of Foolish Behaviour 4th of July Pre-Party">Foolish Behaviour 4th of July Pre-Party</a> <span>at <a href="/club.aspx?id=41317">The Music Room</a></span></h1><div class="grey event-lineup">ReVamp, Ralph &amp; Louie, DJ Provost</div><p class="attending"><span>1</span> Attending</p></div></article></li><li><p class="eventDate date"><a href="/events.aspx?ai=64&amp;v=day&amp;mn=7&amp;yr=2019&amp;dy=4"><span>Thu, 04 Jul 2019 /</span></a></p></li><li class=""><article class="event-item clearfix" itemscope="" itemtype="http://data-vocabulary.org/Event"><span style="display:none;"><time datetime="2019-07-04T00:00" itemprop="startDate">2019-07-04T00:00</time></span><a href="/events/1304933"><img height="76" src="/images/events/flyer/2019/7/us-0704-1304933-list.jpg" width="152"/></a><div class="bbox"><h1 class="event-title" itemprop="summary"><a href="/events/1304933" itemprop="url" title="Event details of Souled Out Party">Souled Out Party</a> <span>at <a href="/club.aspx?id=166493">Gallery 992</a></span></h1><div class="grey event-lineup">Stan Zeff</div></div></article></li><li><p class="eventDate date"><a href="/events.aspx?ai=64&amp;v=day&amp;mn=7&amp;yr=2019&amp;dy=5"><span>Fri, 05 Jul 2019 /</span></a></p></li><li class=""><article class="event-item clearfix" itemscope="" itemtype="http://data-vocabulary.org/Event"><span style="display:none;"><time datetime="2019-07-05T00:00" itemprop="startDate">2019-07-05T00:00</time></span><a href="/events/1286432"><img height="76" src="/images/events/flyer/2019/7/us-0705-1286432-list.jpg" width="152"/></a><div class="bbox"><h1 class="event-title" itemprop="summary"><a href="/events/1286432" itemprop="url" title="Event details of Proper Taste: Feat. João &amp; Elio Stereo">Proper Taste: Feat. João &amp; Elio Stereo</a> <span>at <a href="/club.aspx?id=151882">Midcity Cafe</a></span></h1><div class="grey event-lineup">João, Elio Stereo, Proper Taste</div><p class="attending"><span>4</span> Attending</p></div></article></li><li><p class="eventDate date"><a href="/events.aspx?ai=64&amp;v=day&amp;mn=7&amp;yr=2019&amp;dy=6"><span>Sat, 06 Jul 2019 /</span></a></p></li><li class=""><article class="event-item clearfix" itemscope="" itemtype="http://data-vocabulary.org/Event"><span style="display:none;"><time datetime="2019-07-06T00:00" itemprop="startDate">2019-07-06T00:00</time></span><a href="/events/1272412"><img height="76" src="/images/events/flyer/2019/7/us-0706-1272412-list.jpg" width="152"/></a><div class="bbox"><h1 class="event-title" itemprop="summary"><a href="/events/1272412" itemprop="url" title="Event details of Desert Hearts feat. Mikey Lion, Lee Reynolds, &amp; Marbs">Desert Hearts feat. Mikey Lion, Lee Reynolds, &amp; Marbs</a> <span>at <a href="/club.aspx?id=157984">Ravine</a></span></h1><div class="grey event-lineup">Desert Hearts ft. Mikey Lion, Lee Reynolds, Marbs</div><p class="attending"><span>1</span> Attending</p></div></article></li>
# </ul>
# </div>
# <div class="fl col2" style="padding-top: 88px;">
# <div class="pr8 sticky">
# <section id="calendar">
# <div class="h-align">
# <h1 class="heading">Calendar</h1>
# </div>
# <div id="calendar-inner">
# <select id="ddlCalendarMonth" name="ctl00$ctl00$cphContent$_contentmain$ucCalendar$ddlCalendarMonth" style="width:104px;">
# <option value="12">December</option>
# <option value="11">November</option>
# <option value="10">October</option>
# <option value="9">September</option>
# <option value="8">August</option>
# <option selected="selected" value="7">July</option>
# <option value="6">June</option>
# <option value="5">May</option>
# <option value="4">April</option>
# <option value="3">March</option>
# <option value="2">February</option>
# <option value="1">January</option>
# </select>
# <select id="ddlCalendarYear" name="ctl00$ctl00$cphContent$_contentmain$ucCalendar$ddlCalend
#                 : "0" + $('#ddlCalendarMonth').val();
#
#             var day = $('#hfCalendarDayOfWeek').val().length === 2
#                 ? $('#hfCalendarDayOfWeek').val()
#                 : "0" + $('#hfCalendarDayOfWeek').val();
#
#             var area = $('#liArea span').text().toLowerCase() === 'all'
#                 ? ""
#                 : $('#liArea span').text();
#
#             var country = area === ''
#                 ? $('#country-name').val()
#                 : $('#liCountry span').text()
#
# 			sQueryString = "/events/"
#                 + country.replace(/[^A-Z0-9]/ig, '').toLowerCase() + "/"
#                 + area.replace(/[^A-Z0-9À-ž]/ig, '').toLowerCase().normalize("NFD").replace(/[\u0300-\u036f]/g, "") + "/"
#                 + $('#ddlCalendarType').val() + "/"
# 				+ $('#ddlCalendarYear').val() + "-"
#                 + month + "-"
# 				+ day;
#
# 			location.href = sQueryString;
# 		});
# 	</script>
# </section>
# <div class="banner">
# <div id="pnlMPU">
# <div class="ad" id="div-gpt-ad-1452773484957-7" style="width: 300px; min-height: 250px; padding-bottom: 10px;"></div>
# </div>
# </div>
# </div>
# </div>
# <div class="fl col2 h-align-toplist">
# <div class="mr8">
# <section class="top-list generic events" id="toplist">
# <h1 class="heading">Top Georgia clubs</h1>
# <ul>
# <li><a ga-event-action="The Sound Table" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=27112">The Sound Table</a> /</li><li><a ga-event-action="The Music Room" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=41317">The Music Room</a> /</li><li><a ga-event-action="Ravine" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=157984">Ravine</a> /</li><li><a ga-event-action="The Tabernacle" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=6143">The Tabernacle</a> /</li><li><a ga-event-action="Space 2" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=67798">Space 2</a> /</li><li><a ga-event-action="Masquerade" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=12045">Masquerade</a> /</li><li><a ga-event-action="The Earl" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=17664">The Earl</a> /</li><li><a ga-event-action="Terminal West" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=73406">Terminal West</a> /</li><li><a ga-event-action="District Atlanta" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=156556">District Atlanta</a> /</li><li><a ga-event-action="The Bakery Atlanta" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=145721">The Bakery Atlanta</a> /</li><li><a ga-event-action="Drunken Unicorn" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=25085">Drunken Unicorn</a> /</li><li><a ga-event-action="The 529" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=56892">The 529</a> /</li>
# </ul>
# <div class="but"><a ga-event-action="see-more" ga-event-category="top-clubs" ga-on="click" href="/clubs.aspx?ai=64">More Georgia clubs</a></div>
# </section><section class="top-list generic events" id="toplist">
# <h1 class="heading">Top 20 regions</h1>
# <ul>
# <li><a ga-event-action="London" ga-event-category="top-regions" ga-on="click" href="/guide/uk/london">London, UK</a> /</li><li><a ga-event-action="Ibiza" ga-event-category="top-regions" ga-on="click" href="/guide/es/ibiza">Ibiza, ES</a> /</li><li><a ga-event-action="Berlin" ga-event-category="top-regions" ga-on="click" href="/guide/de/berlin">Berlin, DE</a> /</li><li><a ga-event-action="All" ga-event-category="top-regions" ga-on="click" href="/guide/streamland">Streamland</a> /</li><li><a ga-event-action="Amsterdam" ga-event-category="top-regions" ga-on="click" href="/guide/nl/amsterdam">Amsterdam, NL</a> /</li><li><a ga-event-action="Barcelona" ga-event-category="top-regions" ga-on="click" href="/guide/es/barcelona">Barcelona, ES</a> /</li><li><a ga-event-action="Paris" ga-event-category="top-regions" ga-on="click" href="/guide/fr/paris">Paris, FR</a> /</li><li><a ga-event-action="Tokyo" ga-event-category="top-regions" ga-on="click" href="/guide/jp/tokyo">Tokyo, JP</a> /</li><li><a ga-event-action="New York" ga-event-category="top-regions" ga-on="click" href="/guide/us/newyork">New York, US</a> /</li><li><a ga-event-action="South + East" ga-event-category="top-regions" ga-on="click" href="/guide/uk/southeast">South + East, UK</a> /</li><li><a ga-event-action="Prague" ga-event-category="top-regions" ga-on="click" href="/guide/cz/prague">Prague, CZ</a> /</li><li><a ga-event-action="All" ga-event-category="top-regions" ga-on="click" href="/guide/croatia">Croatia</a> /</li><li><a ga-event-action="Manchester" ga-event-category="top-regions" ga-on="click" href="/guide/uk/manchester">Manchester, UK</a> /</li><li><a ga-event-action="Glasgow" ga-event-category="top-regions" ga-on="click" href="/guide/uk/glasgow">Glasgow, UK</a> /</li><li><a ga-event-action="Midlands" ga-event-category="top-regions" ga-on="click" href="/guide/uk/midlands">Midlands, UK</a> /</li><li><a ga-event-action="Zurich" ga-event-category="top-regions" ga-on="click" href="/guide/ch/zurich">Zurich, CH</a> /</li><li><a ga-event-action="North" ga-event-category="top-regions" ga-on="click" href="/guide/uk/north">North, UK</a> /</li><li><a ga-event-action="Other regions" ga-event-category="top-regions" ga-on="click" href="/guide/nl/otherregions">Other regions, NL</a> /</li><li><a ga-event-action="All" ga-event-category="top-regions" ga-on="click" href="/guide/belgium">Belgium</a> /</li><li><a ga-event-action="South" ga-event-category="top-regions" ga-on="click" href="/guide/es/south">South, ES</a> /</li>
# </ul>
# <div class="but"><a ga-event-action="see-more" ga-event-category="top-regions" ga-on="click" href="/events.aspx?show=all">More regions</a></div>
# </section><div id="pnlSkyscraper">
# <div class="ad mobile-off" id="div-gpt-ad-1452773484957-12" style="width: 160px; height: 600px;"></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="page-items content sub clearfix">
# <ul>
# <li class="but arrow-left left" id="liPrevious2">
# <a ga-event-action="Previous " ga-event-category="event-listings" ga-on="click" href="/events/us/georgia/week/2019-06-24">Previous </a>
# </li><li class="but arrow-right right" id="liNext2">
# <a ga-event-action="Next " ga-event-category="event-listings" ga-on="click" href="/events/us/georgia/week/2019-07-08">Next </a>
# </li>
# </ul>
# </div>
# <div class="banner clearfix">
# <div id="pnlECTOSlot2" style="text-align: center;">
# <div class="ad" id="div-gpt-ad-1452773484957-1"></div>
# </div>
# </div>
# <br/>
# <span>01 /</span>
# </li>
# <li class="alt">
# <section class="content" id="popular-news">
# <h1 class="heading listing-heading">Most popular news</h1>
# <div class="but heading-more mobile-off">
# <a ga-event-action="see-more" ga-event-category="news" ga-on="click" href="/news">More news</a>
# </div>
# <div class="strip small slide" data-type="news" id="news-listing">
# <ul class="list">
# <li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Wed, 01 Jul 2020</p>
# <a href="/news/72186">
# <img class="thumb" src="/images/news/2020/bsh-island-festival-croatia-zcre-beach.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/72186/?comments=1">Post a comment</a>
# </p><a href="/news/72186">
# <h1>Coronavirus latest: Some European festivals will go ahead in 2020, New York's Nowadays, Elsewhere reopen outdoor spaces</h1>
# </a>
# <p class="copy">Everything we know about how COVID-19 (the disease caused by the novel coronavirus) is affecting the electronic music scene.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Tue, 30 Jun 2020</p>
# <a href="/news/72624">
# <img class="thumb" src="/images/news/2020/nightclubs-coronavirus-reopenings.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/72624/?comments=1">Post a comment</a>
# </p><a href="/news/72624">
# <h1>How countries plan to restart nightclubs and music festivals</h1>
# </a>
# <p class="copy">The latest on club reopenings, closings and music festivals affected by COVID-19.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Mon, 29 Jun 2020</p>
# <a href="/news/72920">
# <img class="thumb" src="/images/news/2020/amnesia-2020-private.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/72920/?comments=1">Post a comment</a>
# </p><a href="/news/72920">
# <h1>130 people evicted from private party at Amnesia Ibiza</h1>
# </a>
# <p class="copy">The local authorities vacated the venue, which currently isn't allowed to open, in the early hours of Sunday morning.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Thu, 25 Jun 2020</p>
# <a href="/news/72909">
# <img class="thumb" src="/images/news/2020/larry-heard-robert-owens-lawsuit-trax-records.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/72909/?comments=1">Post a comment</a>
# </p><a href="/news/72909">
# <h1>Larry Heard and Robert Owens file lawsuit against Trax Records for unpaid royalties and exploitation</h1>
# </a>
# <p class="copy">The lawsuit covers the duo's classic work in the '80s, seeking at least $1 million in damages.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Fri, 26 Jun 2020</p>
# <a href="/news/72902">
# <img class="thumb" src="/images/news/2020/kevin-saunderson-billboard-interview-detroit-techno.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/72902/?comments=1">Post a comment</a>
# </p><a href="/news/72902">
# <h1>Kevin Saunderson: 'You feel like somebody is eliminating Black artists and producers from being part of the scene'</h1>
# </a>
# <p class="copy">The Detroit techno pioneer spoke to Billboard about the differences in US and European scenes, dismissive conversations with executives, goals for the industry and more.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Tue, 30 Jun 2020</p>
# <a href="/news/72931">
# <img class="thumb" src="/images/news/2020/flaming-club-zurich-coronavirus-quarantine.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/72931/?comments=1">Post a comment</a>
# </p><a href="/news/72931">
# <h1>Switzerland orders 300 Zurich clubgoers to quarantine after one tests positive for coronavirus</h1>
# </a>
# <p class="copy">One infected person visited the Flamingo Club last week, and at least five other attendees in their group also tested positive.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Wed, 01 Jul 2020</p>
# <a href="/news/72944">
# <img class="thumb" src="/images/news/2020/ra-rs-photos.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/72944/?comments=1">Post a comment</a>
# </p><a href="/news/72944">
# <h1>RA launches subscription service, Resident Subscriber</h1>
# </a>
# <p class="copy">With one-off, monthly and annual subscription options available, Resident Subscribers will receive exclusive access, merch and gallery-quality prints.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Fri, 26 Jun 2020</p>
# <a href="/news/72912">
# <img class="thumb" src="/images/news/2020/daniel-avery-surprise-new-album-love-light-lockdown-photo.jpeg"/>
# </a>
# <p class="comments light">
# <a href="/news/72912/?comments=1">Post a comment</a>
# </p><a href="/news/72912">
# <h1>Daniel Avery releases new album, Love + Light</h1>
# </a>
# <p class="copy">Produced during lockdown, the 14-track surprise LP is out now on Phantasy.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Mon, 29 Jun 2020</p>
# <a href="/news/72924">
# <img class="thumb" src="/images/news/2020/mixmag-pausing-print-magazine.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/72924/?comments=1">Post a comment</a>
# </p><a href="/news/72924">
# <h1>Mixmag 'pauses' print magazine</h1>
# </a>
# <p class="copy">The long-running dance music publication will return to print next year.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Sat, 27 Jun 2020</p>
# <a href="/news/72916">
# <img class="thumb" src="/images/news/2020/a-g-and-manara-mix-of-the-day.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/72916/?comments=1">Post a comment</a>
# </p><a href="/news/72916">
# <h1>Mix Of The Day: A.G &amp; Manara</h1>
# </a>
# <p class="copy">The ecstatic latest episode of the duo's Beauty Blender show on NTS.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Fri,
</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Fri, 26 Jun 2020</p>
# <a href="/news/72917">
# <img class="thumb" src="/images/news/2020/sparkle-division-basinski.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/72917/?comments=1">Post a comment</a>
# </p><a href="/news/72917">
# <h1>William Basinski and Preston Wendel's SPARKLE DIVISION reveals debut album</h1>
# </a>
# <p class="copy">To Feel Embraced features the late free jazz bassist Henry Grimes, Mrs. Leonora Russo and Xeli Grana.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Wed, 01 Jul 2020</p>
# <a href="/news/72938">
# <img class="thumb" src="/images/news/2020/ge-ology-mix-of-the-da.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/72938/?comments=1">Post a comment</a>
# </p><a href="/news/72938">
# <h1>Mix Of The Day: Ge-ology</h1>
# </a>
# <p class="copy">A cathartic four-hour, all-vinyl set from the Brooklyn artist.</p>
# </article>
# </li> </ul>
# </div>
# <div class="link-more mobile-only tablet-off">
# <a ga-event-action="see-more" ga-event-category="news" ga-on="click" href="/news">More news</a>
# </div>
# </section>
# <span>02 /</span>
# </li>
# </ul>
# </main>
# </form>
# <footer class="clearfix"><ul class="content-list">
# <li>
# <div class="content clearfix">
# <div class="clearfix plus8">
# <div class="fl col2-3">
# <ul class="pb32">
# <li id="logo-footer"><a href="/">RA</a></li>
# <li class="f12 grey pt16">Copyright © 2020 Resident Advisor Ltd.</li>
# <li class="f12 grey">All rights reserved.</li>
# <li class="f12 grey"><a href="/privacy">Privacy</a> &amp; <a href="/terms">Terms</a></li>
# <li class="f12 grey"><a href="/cookiepolicy">Cookie Policy</a></li>
# </ul>
# </div>
# <div class="fl col4-5 pt60">
# <div class="fl col1 footer-category">
# <ul>
# <li class="f12 grey">Resident Advisor /</li> <li><a ga-event-action="about" ga-event-category="homefooter" ga-on="click" href="/about">About</a></li>
# <li><a ga-event-action="advertise" ga-event-category="homefooter" ga-on="click" href="/about/advertising">Advertise</a></li>
# <li><a ga-event-action="jobs" ga-event-category="homefooter" ga-on="click" href="https://www.doorsopen.co/company/12/resident-advisor/#utm_source=RA&amp;utm_medium=footer-link">Jobs</a></li>
# <li><a ga-event-action="raevents" ga-event-category="homefooter" ga-on="click" href="/features/3214">24/7</a></li>
# <li><a ga-event-action="store" ga-event-category="homefooter" ga-on="click" href="https://store.ra.co">RA Store</a></li>
# <li><br/></li> </ul>
# </div>
# <div class="fl col1 footer-category">
# <ul>
# <li class="f12 grey">RA Tickets /</li>
# <li><a ga-event-action="mytickets" ga-event-category="homefooter" ga-on="click" href="/shop/history">My Tickets</a></li>
# <li><a ga-event-action="ticketfaq" ga-event-category="homefooter" ga-on="click" href="/shop/faq">Ticketing FAQ</a></li>
# <li><a ga-event-action="resale" ga-event-category="homefooter" ga-on="click" href="/tickets/resale">Resale</a></li>
# <li><a ga-event-action="selltickets" ga-event-category="homefooter" ga-on="click" href="/tickets">Sell tickets on RA</a></li>
# <li><div class="myra but" style="width: 152px; margin-top: 50px;"><a class="submit-event" ga-event-action="submitevent" ga-event-category="homefooter" ga-on="click" href="/submit-event.aspx">Submit event</a></div></li>
# <li><br/></li>
# </ul>
# </div>
# <div class="fl col1 footer-category">
# <ul>
# <li class="f12 grey">Apps /</li> <li><a ga-event-action="raguide" ga-event-category="homefooter" ga-on="click" href="/ra-guide">RA Guide</a></li>
# <li><a ga-event-action="ticketscanner" ga-event-category="homefooter" ga-on="click" href="/tickets/scanner">RA Ticket Scanner</a></li> </ul>
# </div>
# <div class="fl col1 footer-category">
# <ul>
# <li class="f12 grey">Elsewhere /</li>
# <li><a ga-event-action="rayoutube" ga-event-category="homefooter" ga-on="click" href="http://www.youtube.com/user/residentadvisor?sub_confirmation=1">Watch on YouTube</a></li>
# <li><a ga-event-action="rafacebook" ga-event-category="homefooter" ga-on="click" href="http://www.facebook.com/residentadvisor">Follow on Facebook</a></li>
# <li><a ga-event-action="raapplemusic" ga-event-category="homefooter" ga-on="click" href="https://itunes.apple.com/gb/curator/resident-advisor/id996091687">Listen on Apple Music</a></li>
# <li><a ga-event-action="raspotify" ga-event-category="homefooter" ga-on="click" href="https://open.spotify.com/user/residentadvisor">Stream on Spotify</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="nobreak">
# <div class="content clearfix">
# <div class="clearfix plus8">
# <div class="fl col3">
# <a href="https://jp.residentadvisor.net/"></a><a href="https://jp.residentadvisor.net/">RA is also available in Japanese. 日本版</a>
# </div>
# <ul class="col1p5" id="social">
# <li class="ytb"><a ga-event-action="rayoutube" ga-event-category="homefooter" ga-on="click" href="http://www.youtube.com/residentadvisor">RA on YouTube</a></li>
# <li class="fcb"><a ga-event-action="rafacebook" ga-event-category="homefooter" ga-on="click" href="http://www.facebook.com/residentadvisor">RA on Facebook</a></li>
# <li class="twt"><a ga-event-action="ratwitter" ga-event-category="homefooter" ga-on="click" href="http://www.twitter.com/residentadvisor">RA on Twitter</a></li>
# <li class="ins"><a ga-event-action="rainstagram" ga-event-category="homefooter" ga-on="click" href="http://instagram.com/resident_advisor">RA on Instagram</a></li>
# <li class="snd"><a ga-event-action="rasoundcloud" ga-event-category="homefooter" ga-on="click" href="http://www.soundcloud.com/resident-advisor">RA on Soundcloud</a></li>
# </ul>
# </div>
# </div>
# </li>
# </ul></footer>
# <script type="text/javascript">
#         (function(i, s, o, g, r, a, m) {
#                                         i['GoogleAnalyticsObject'] = r;
#                                         i[r] = i[r] || function() {
#                                             (i[r].q = i[r].q || []).push(arguments)
#                                         }, i[r].l = 1 * new Date();
#                                         a = s.createElement(o), m = s.getElementsByTagName(o)[0];
#                                         a.async = 1;
#                                         a.src = g;
#                                         m.parentNode.insertBefore(a, m)
#                                     })(window, document, 'script', '//www.google-analytics.com/analytics.js', 'ga');
#                                     ga('create', 'UA-313318-1', 'residentadvisor.net'
#                                     );
#                                     ga('require', 'displayfeatures');
#                                     ga('send', 'pageview');
#                                     ga('require', 'eventTracker');
#
#         if (window.location.href.indexOf('.residentadvisor.net') >= 0 && window.location.pathname.indexOf('submit-event') === 0) {
# 	        (function(r, a, v, e, l, i, n) {
# 	            r[l] = r[l] || function() { (r[l].q = r[l].q || []).push(arguments) };
# 	            i = a.createElement(v);
# 	            i.async = i.defer = 1;
# 	            i.src = e;
# 	            a.body.appendChild(i)
# 	        })(window, document, 'script', 'https://cdn.ravelin.net/js/rvn-beta.min.js', 'ravelin');
# 	        ravelin('setApiKey', 'pk_live_Z6F2v32uJEQnwn46SLF7xdojmnOPLfAI');
#             ravelin('setCustomerId', '0');
#             ravelin('setCookieDomain', '.residentadvisor.net');
# 	    }
# 	</script>
# <script>
#         cssVars({})
#     </script>
# </body>
# </html>>

# %%
event_name = soup.find_all('h1', class_='event-title')

# %%
event_name
for event in event_name:
    print(event.text)
# Out:
# Foolish Behaviour 4th of July Pre-Party at The Music Room
# Souled Out Party at Gallery 992
# Proper Taste: Feat. João & Elio Stereo at Midcity Cafe
# Desert Hearts feat. Mikey Lion, Lee Reynolds, & Marbs at Ravine
# <h1 class="event-title" itemprop="summary"><a href="/events/1273253" itemprop="url" title="Event details of Foolish Behaviour 4th of July Pre-Party">Foolish Behaviour 4th of July Pre-Party</a> <span>at <a href="/club.aspx?id=41317">The Music Room</a></span></h1>

# %%
event_date = soup.find_all('p', class_='eventDate date')
for date in event_date:
    print(date.text[0:-2])
# Out:
# Wed, 03 Jul 2019
# Thu, 04 Jul 2019
# Fri, 05 Jul 2019
# Sat, 06 Jul 2019

# %%
attending = soup.find_all('p', class_='attending')
for attendee in attending:
    print(attendee.text[0])
    
    
attending
# Out:
# 1
# 4
# 1
# [<p class="attending"><span>1</span> Attending</p>,
#  <p class="attending"><span>4</span> Attending</p>,
#  <p class="attending"><span>1</span> Attending</p>]

# %%
attending2 = soup.find_all('div', class_='grey event-lineup')

atten2 = [atten.nextSibling for atten in attending2]
atten3 = []
for number in atten2:
    if number == None:
        atten3.append(0)
    else:
        atten3.append(number.text[0])
        
atten3
# Out:
# ['1', 0, '4', '1']

# %%
container = soup.find_all('h1', class_="event-title")
venues = None
for place in container:
    place.findChildren('span')
    for venue in place.findChildren('span'):
        venue.findChildren('a')
        for location in venue.findChildren('a'):
            print(location.text)
# Out:
# The Music Room
# Gallery 992
# Midcity Cafe
# Ravine

# %%
concert = event_name[2].text

# %%
concert = concert.replace('\n', '')
concert
# Out:
# 'Proper Taste: Feat. João & Elio Stereo at Midcity Cafe'

# %% [markdown]
# ## Write a Function to Scrape all of the Events on the Given Page Events Page
#
# The function should return a Pandas DataFrame with columns for the Event_Name, Venue, Event_Date and Number_of_Attendees.

# %%
def scrape_events(events_page_url):
    html_page = requests.get(events_page_url)
    soup = BeautifulSoup(html_page.content, 'lxml')
    
    event_names = [name.text for name in soup.find_all('h1', class_='event-title')]
    
    venues = []
    for place in container:
        place.findChildren('span')
        for venue in place.findChildren('span'):
            venue.findChildren('a')
            for location in venue.findChildren('a'):
                venues.append(location.text)
    
    
    event_date = [date.text[0:-2] for date in soup.find_all('p', class_='eventDate date')]
    attendees = [attendee.nextSibling for attendee in soup.find_all('div', class_='grey event-lineup')]
    attendees_clean = []
    for number in attendees:
        if number == None:
            attendees_clean.append(0)
        else:
            attendees_clean.append(number.text[0])
        
    
    df = pd.DataFrame([event_names, venues, event_date, attendees_clean]).transpose()
    df.columns = ["Event_Name", "Venue", "Event_Date", "Number_of_Attendees"]
    return df

# %%
scrape_events('https://www.residentadvisor.net/events/us/georgia/week/2019-07-01')
# Out:
#                                           Event_Name           Venue  \
# 0  Foolish Behaviour 4th of July Pre-Party at The...  The Music Room
# 1                    Souled Out Party at Gallery 992     Gallery 992
# 2  Proper Taste: Feat. João & Elio Stereo at Midc...    Midcity Cafe
# 3  Desert Hearts feat. Mikey Lion, Lee Reynolds, ...          Ravine
#
#          Event_Date Number_of_Attendees
# 0  Wed, 03 Jul 2019                   1
# 1  Thu, 04 Jul 2019                   0
# 2  Fri, 05 Jul 2019                   4
# 3  Sat, 06 Jul 2019                   1

# %% [markdown]
# ## Write a Function to Retrieve the URL for the Next Page

# %%
def next_page(url):
    #Your code here
    response = requests.get(url)
    soup = BeautifulSoup(response.content , 'lxml')
    url_ext = soup.find('a', attrs={'ga-event-action':"Next "}).attrs['href']
    next_page_url = "https://www.residentadvisor.net"+url_ext
    return next_page_url

# %% [markdown]
# ## Scrape the Next 1000 Events for Your Area
#
# Display the data sorted by the number of attendees. If there is a tie for the number attending, sort by event date.

# %%
#Your code here
dfs = []
total_rows = 0
cur_url = "https://www.residentadvisor.net/events/us/georgia/week/2016-07-01"
while total_rows <= 1000:
    df = scrape_events(cur_url)
    dfs.append(df)
    total_rows += len(df)
    cur_url = next_page(cur_url)
    time.sleep(.2)
    
df = pd.concat(dfs)
df = df.iloc[:1000]
print(len(df))
df.head(20)
# Out:
# 1000
#                                           Event_Name           Venue  \
# 0  Crew Love: Soul Clap, Wolf + Lamb, Nick Monaco...  The Music Room
# 1  &Me, Baez, Jeremy Ismael, Tocayo & More at The...     Gallery 992
# 2                                               None    Midcity Cafe
# 3                                               None          Ravine
# 0  Wiggle Factor & Atlanta Techno Love present Cl...  The Music Room
#
#          Event_Date Number_of_Attendees
# 0  Sat, 02 Jul 2016                   2
# 1  Sun, 03 Jul 2016                   1
# 2              None                None
# 3              None                None
# 0  Sat, 09 Jul 2016                   6

# %%
df.head(20)
# Out:
#                                           Event_Name           Venue  \
# 0  Crew Love: Soul Clap, Wolf + Lamb, Nick Monaco...  The Music Room
# 1  &Me, Baez, Jeremy Ismael, Tocayo & More at The...     Gallery 992
# 2                                               None    Midcity Cafe
# 3                                               None          Ravine
# 0  Wiggle Factor & Atlanta Techno Love present Cl...  The Music Room
# 1  Roman Flügel (TIX Sold at Door) at The Alley C...     Gallery 992
# 2                                               None    Midcity Cafe
# 3                                               None          Ravine
# 0  Stripped Records Record Release Party with Nor...  The Music Room
# 1  Tyrone Francis - Celebrating 50 Years of Life ...     Gallery 992
# 2                                               None    Midcity Cafe
# 3                                               None          Ravine
# 0  Fur Coat (Crosstown Rebels) at The Alley Cat M...  The Music Room
# 1                    Soul 2 Seoul at The Sound Table     Gallery 992
# 2          Sunset: Friends & Family at TBA - Atlanta    Midcity Cafe
# 3  Wiggle Factor presents Form X with Truncate at...          Ravine
# 4  404 on the Floor: Back to Basics Vol. 1: Karl ...            None
# 5                Good Vibes Summer 16 at Red Martini            None
# 0                             Argot Music at Space 2  The Music Room
# 1          4yo4u (Minus) at The Alley Cat Music Club     Gallery 992
#
#          Event_Date Number_of_Attendees
# 0  Sat, 02 Jul 2016                   2
# 1  Sun, 03 Jul 2016                   1
# 2              None                None
# 3              None                None
# 0  Sat, 09 Jul 2016                   6
# 1  Thu, 14 Jul 2016                   7
# 2              None                None
# 3              None                None
# 0  Fri, 15 Jul 2016                   2
# 1  Sat, 16 Jul 2016                   1
# 2              None                None
# 3              None                None
# 0  Fri, 22 Jul 2016                   1
# 1  Sat, 23 Jul 2016                   3
# 2  Tue, 26 Jul 2016                   8
# 3              None                   3
# 4              None                   1
# 5              None                   0
# 0  Fri, 29 Jul 2016                   1
# 1  Sat, 30 Jul 2016                   1

# %% [markdown]
# ## Summary
#
# Congratulations! In this lab, you successfully developed a pipeline to scrape a website for concert event information!
